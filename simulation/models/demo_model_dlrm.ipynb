# %%
def DLRMTetris():
    tetris_size = {}
    r = 0
    gr = 0

    for r in range(64):
        tetris_size[r] = 9980333
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 36084
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 17217
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 7378
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 20134
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 3
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 7112
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 1442
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 61
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 9758201
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 1333352
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 313829
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 10
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 2208
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 11156
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 122
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 4
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 970
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 14
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 9994222
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 7267859
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 9946608
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 415421
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 12420
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 101
    gr += 64

    for r in range(64):
        tetris_size[gr+r] = 36
    gr += 64

    for r in range(512):
        tetris_size[gr+r] = 13
    gr += 512

    for r in range(256):
        tetris_size[gr+r] = 512
    gr += 256

    for r in range(64):
        tetris_size[gr+r] = 256
    gr += 64

    for r in range(512):
        tetris_size[gr+r] = 415
    gr += 512

    for r in range(512):
        tetris_size[gr+r] = 512
    gr += 512

    for r in range(256):
        tetris_size[gr+r] = 512
    gr += 256

    for r in range(1):
        tetris_size[gr+r] = 256
    gr += 1
    
    return tetris_size


tetris_size = DLRMTetris()

# %%
import matplotlib.pyplot as plt


plt.figure()
plt.plot(tetris_size.keys(), tetris_size.values(), linestyle="-", marker=".")
plt.xlabel("Vector index")
plt.ylabel("Length of the vector")
plt.yscale("log")
plt.show()

# %%
import pickle

pickle.dump(list(tetris_size.values()), open("../../data/saved_models_shape/dlrm/embedding.p", "wb"))

print("model saved in pickle files")
# Out:
# model saved in pickle files
